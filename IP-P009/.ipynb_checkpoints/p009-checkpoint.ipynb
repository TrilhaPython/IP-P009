# %% [markdown]
# 1. Carregar agora os dados dos dois datasets utilizando um DateTimeIndex ;

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataframe2003 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2003_A_31-12-2003.CSV', sep=';', encoding='ISO-8859-1' , decimal = ',')
dataframe2013 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2013_A_31-12-2013.CSV', sep=';', encoding='ISO-8859-1', decimal = ',')
dataframe2023 = pd.read_csv('./datasets/INMET_CO_MT_A901_CUIABA_01-01-2023_A_31-12-2023.CSV', sep=';', encoding='ISO-8859-1', decimal = ',')

# %%
dataframe2003.head()
# Out:
#          DATA HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (MM)  \
# 0  01/01/2003      00:00                           -9999.0
# 1  01/01/2003      01:00                           -9999.0
# 2  01/01/2003      02:00                           -9999.0
# 3  01/01/2003      03:00                           -9999.0
# 4  01/01/2003      04:00                           -9999.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                            -9999.0
# 1                                            -9999.0
# 2                                            -9999.0
# 3                                            -9999.0
# 4                                            -9999.0
#
#    PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                          -9999.0
# 1                                          -9999.0
# 2                                          -9999.0
# 3                                          -9999.0
# 4                                          -9999.0
#
#    PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/mý)  \
# 0                                           -9999.0                    -9999
# 1                                           -9999.0                    -9999
# 2                                           -9999.0                    -9999
# 3                                           -9999.0                    -9999
# 4                                           -9999.0                    -9999
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# 0                                          24.3
# 1                                          24.7
# 2                                          24.4
# 3                                          24.1
# 4                                          24.5
#
#    TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# 0                                  23.3
# 1                                  23.3
# 2                                  23.2
# 3                                  23.2
# 4                                  23.4
#
#    TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# 0                                        24.7
# 1                                        24.7
# 2                                        24.7
# 3                                        24.9
# 4                                        24.6
#
#    TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# 0                                        24.3
# 1                                        24.3
# 2                                        24.4
# 3                                        24.1
# 4                                        24.1
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# 0                                              23.4
# 1                                              23.4
# 2                                              23.4
# 3                                              23.5
# 4                                              23.5
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# 0                                           -9999.0
# 1                                           -9999.0
# 2                                           -9999.0
# 3                                           -9999.0
# 4                                           -9999.0
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        94
# 1                                        94
# 2                                        93
# 3                                        95
# 4                                        95
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        92
# 1                                        92
# 2                                        91
# 3                                        92
# 4                                        93
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇO HORARIA (gr) (ø (gr))  \
# 0                                   94                                 -9999
# 1                                   92                                 -9999
# 2                                   93                                 -9999
# 3                                   95                                 -9999
# 4                                   94                                 -9999
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)
# 0                     -9999.0                          -9999.0
# 1                     -9999.0                          -9999.0
# 2                     -9999.0                          -9999.0
# 3                     -9999.0                          -9999.0
# 4                     -9999.0                          -9999.0

# %%
dataframe2013.head()
# Out:
#          DATA HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2013      00:00                               0.4
# 1  01/01/2013      01:00                               1.2
# 2  01/01/2013      02:00                               0.4
# 3  01/01/2013      03:00                               0.0
# 4  01/01/2013      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              983.5
# 1                                              983.9
# 2                                              984.4
# 3                                              984.9
# 4                                              984.3
#
#    PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            983.5
# 1                                            984.0
# 2                                            984.5
# 3                                            985.0
# 4                                            984.9
#
#    PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/mý)  \
# 0                                             982.1                  -9999.0
# 1                                             983.5                  -9999.0
# 2                                             983.9                  -9999.0
# 3                                             984.4                  -9999.0
# 4                                             984.3                  -9999.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# 0                                          26.1
# 1                                          24.7
# 2                                          24.5
# 3                                          24.4
# 4                                          24.4
#
#    TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# 0                                  21.9
# 1                                  22.7
# 2                                  22.8
# 3                                  22.9
# 4                                  22.9
#
#    TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# 0                                        28.1
# 1                                        26.1
# 2                                        24.9
# 3                                        24.5
# 4                                        24.4
#
#    TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# 0                                        26.1
# 1                                        24.5
# 2                                        24.5
# 3                                        24.2
# 4                                        24.2
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# 0                                              22.0
# 1                                              22.9
# 2                                              23.2
# 3                                              22.9
# 4                                              23.0
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# 0                                              20.7
# 1                                              22.2
# 2                                              22.5
# 3                                              22.5
# 4                                              22.8
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        78
# 1                                        89
# 2                                        91
# 3                                        92
# 4                                        92
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        64
# 1                                        78
# 2                                        88
# 3                                        90
# 4                                        91
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇO HORARIA (gr) (ø (gr))  \
# 0                                   78                                   145
# 1                                   89                                   184
# 2                                   91                                   247
# 3                                   92                                    98
# 4                                   91                                   123
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)
# 0                         4.3                              2.1
# 1                         4.0                              1.4
# 2                         3.7                              1.6
# 3                         3.5                              1.9
# 4                         3.5                              1.2

# %%
dataframe2023.head()
# Out:
#          DATA  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2023  0000 UTC                               NaN
# 1  01/01/2023  0100 UTC                               NaN
# 2  01/01/2023  0200 UTC                               NaN
# 3  01/01/2023  0300 UTC                               0.0
# 4  01/01/2023  0400 UTC                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              990.5
# 4                                              990.2
#
#    PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                            990.5
# 4                                            990.5
#
#    PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/mý)  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                             990.4                      NaN
# 4                                             990.2                      NaN
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                          27.5
# 4                                          27.3
#
#    TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                  20.6
# 4                                  20.2
#
#    TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        27.9
# 4                                        27.8
#
#    TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        27.5
# 4                                        27.3
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                              20.6
# 4                                              20.7
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                              20.2
# 4                                              20.2
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                      66.0
# 4                                      66.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                      63.0
# 4                                      65.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇO HORARIA (gr) (ø (gr))  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                 66.0                                   NaN
# 4                                 65.0                                   NaN
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN

# %%
#Renomeando coluna do datasets
dataframe2023.rename(columns={'Hora UTC':'HORA (UTC)', 'RADIACAO GLOBAL (Kj/mý)': 'RADIACAO GLOBAL (KJ/mý)'}, inplace=True)
dataframe2003.rename(columns={'PRECIPITAÇÃO TOTAL, HORÁRIO (MM)': 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'},inplace=True)



#Convertendo coluna DATA para datetime
dataframe2003['DATA'] = pd.to_datetime(dataframe2003['DATA'], format='%d/%m/%Y', errors='coerce').dt.strftime('%Y/%m/%d')
dataframe2013['DATA'] = pd.to_datetime(dataframe2013['DATA'], format='%d/%m/%Y', errors='coerce').dt.strftime('%Y/%m/%d')
dataframe2023['DATA'] = pd.to_datetime(dataframe2023['DATA'], format='%d/%m/%Y', errors='coerce').dt.strftime('%Y/%m/%d')

#Tratando HORA (UTC)
dataframe2023['HORA (UTC)'] = dataframe2023['HORA (UTC)'].str.rstrip(' UTC').str.slice_replace(2, 2, ':')

#Juntando datasets
df_concat = pd.concat([dataframe2003, dataframe2013, dataframe2023])
df_concat
# Out:
#             DATA HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2003/01/01      00:00                           -9999.0
# 1     2003/01/01      01:00                           -9999.0
# 2     2003/01/01      02:00                           -9999.0
# 3     2003/01/01      03:00                           -9999.0
# 4     2003/01/01      04:00                           -9999.0
# ...          ...        ...                               ...
# 8755  2023/12/31      19:00                               0.0
# 8756  2023/12/31      20:00                               0.0
# 8757  2023/12/31      21:00                               0.0
# 8758  2023/12/31      22:00                               0.0
# 8759  2023/12/31      23:00                               NaN
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                               -9999.0
# 1                                               -9999.0
# 2                                               -9999.0
# 3                                               -9999.0
# 4                                               -9999.0
# ...                                                 ...
# 8755                                              987.4
# 8756                                              986.7
# 8757                                              986.8
# 8758                                              986.9
# 8759                                                NaN
#
#       PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                             -9999.0
# 1                                             -9999.0
# 2                                             -9999.0
# 3                                             -9999.0
# 4                                             -9999.0
# ...                                               ...
# 8755                                            988.8
# 8756                                            987.4
# 8757                                            986.8
# 8758                                            987.0
# 8759                                              NaN
#
#       PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                              -9999.0
# 1                                              -9999.0
# 2                                              -9999.0
# 3                                              -9999.0
# 4                                              -9999.0
# ...                                                ...
# 8755                                             987.4
# 8756                                             986.7
# 8757                                             986.6
# 8758                                             986.8
# 8759                                               NaN
#
#       RADIACAO GLOBAL (KJ/mý)  TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# 0                     -9999.0                                          24.3
# 1                     -9999.0                                          24.7
# 2                     -9999.0                                          24.4
# 3                     -9999.0                                          24.1
# 4                     -9999.0                                          24.5
# ...                       ...                                           ...
# 8755                   2575.3                                          34.4
# 8756                   1760.8                                          33.4
# 8757                   1127.5                                          32.5
# 8758                    490.1                                          30.8
# 8759                      NaN                                           NaN
#
#       TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# 0                                     23.3
# 1                                     23.3
# 2                                     23.2
# 3                                     23.2
# 4                                     23.4
# ...                                    ...
# 8755                                  19.4
# 8756                                  18.0
# 8757                                  21.8
# 8758                                  21.8
# 8759                                   NaN
#
#       TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# 0                                           24.7
# 1                                           24.7
# 2                                           24.7
# 3                                           24.9
# 4                                           24.6
# ...                                          ...
# 8755                                        35.2
# 8756                                        35.0
# 8757                                        33.9
# 8758                                        32.7
# 8759                                         NaN
#
#       TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# 0                                           24.3
# 1                                           24.3
# 2                                           24.4
# 3                                           24.1
# 4                                           24.1
# ...                                          ...
# 8755                                        33.9
# 8756                                        33.3
# 8757                                        32.1
# 8758                                        30.8
# 8759                                         NaN
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# 0                                                 23.4
# 1                                                 23.4
# 2                                                 23.4
# 3                                                 23.5
# 4                                                 23.5
# ...                                                ...
# 8755                                              20.6
# 8756                                              19.7
# 8757                                              22.0
# 8758                                              21.9
# 8759                                               NaN
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# 0                                              -9999.0
# 1                                              -9999.0
# 2                                              -9999.0
# 3                                              -9999.0
# 4                                              -9999.0
# ...                                                ...
# 8755                                              19.1
# 8756                                              17.9
# 8757                                              18.0
# 8758                                              21.3
# 8759                                               NaN
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                         94.0
# 1                                         94.0
# 2                                         93.0
# 3                                         95.0
# 4                                         95.0
# ...                                        ...
# 8755                                      45.0
# 8756                                      42.0
# 8757                                      55.0
# 8758                                      59.0
# 8759                                       NaN
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         92.0
# 1                                         92.0
# 2                                         91.0
# 3                                         92.0
# 4                                         93.0
# ...                                        ...
# 8755                                      40.0
# 8756                                      39.0
# 8757                                      40.0
# 8758                                      52.0
# 8759                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    94.0
# 1                                    92.0
# 2                                    93.0
# 3                                    95.0
# 4                                    94.0
# ...                                   ...
# 8755                                 41.0
# 8756                                 40.0
# 8757                                 53.0
# 8758                                 59.0
# 8759                                  NaN
#
#       VENTO, DIREÇO HORARIA (gr) (ø (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                  -9999.0                     -9999.0
# 1                                  -9999.0                     -9999.0
# 2                                  -9999.0                     -9999.0
# 3                                  -9999.0                     -9999.0
# 4                                  -9999.0                     -9999.0
# ...                                    ...                         ...
# 8755                                 320.0                         6.6
# 8756                                 339.0                         7.0
# 8757                                 105.0                         6.0
# 8758                                  96.0                         4.0
# 8759                                   NaN                         NaN
#
#       VENTO, VELOCIDADE HORARIA (m/s)
# 0                             -9999.0
# 1                             -9999.0
# 2                             -9999.0
# 3                             -9999.0
# 4                             -9999.0
# ...                               ...
# 8755                              3.0
# 8756                              3.4
# 8757                              2.0
# 8758                              1.5
# 8759                              NaN
#
# [26280 rows x 19 columns]

# %%
df_concat.replace(-9999.0, np.nan, inplace=True)

# %%
df_concat
# Out:
#             DATA HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2003/01/01      00:00                               NaN
# 1     2003/01/01      01:00                               NaN
# 2     2003/01/01      02:00                               NaN
# 3     2003/01/01      03:00                               NaN
# 4     2003/01/01      04:00                               NaN
# ...          ...        ...                               ...
# 8755  2023/12/31      19:00                               0.0
# 8756  2023/12/31      20:00                               0.0
# 8757  2023/12/31      21:00                               0.0
# 8758  2023/12/31      22:00                               0.0
# 8759  2023/12/31      23:00                               NaN
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8755                                              987.4
# 8756                                              986.7
# 8757                                              986.8
# 8758                                              986.9
# 8759                                                NaN
#
#       PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 8755                                            988.8
# 8756                                            987.4
# 8757                                            986.8
# 8758                                            987.0
# 8759                                              NaN
#
#       PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8755                                             987.4
# 8756                                             986.7
# 8757                                             986.6
# 8758                                             986.8
# 8759                                               NaN
#
#       RADIACAO GLOBAL (KJ/mý)  TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# 0                         NaN                                          24.3
# 1                         NaN                                          24.7
# 2                         NaN                                          24.4
# 3                         NaN                                          24.1
# 4                         NaN                                          24.5
# ...                       ...                                           ...
# 8755                   2575.3                                          34.4
# 8756                   1760.8                                          33.4
# 8757                   1127.5                                          32.5
# 8758                    490.1                                          30.8
# 8759                      NaN                                           NaN
#
#       TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# 0                                     23.3
# 1                                     23.3
# 2                                     23.2
# 3                                     23.2
# 4                                     23.4
# ...                                    ...
# 8755                                  19.4
# 8756                                  18.0
# 8757                                  21.8
# 8758                                  21.8
# 8759                                   NaN
#
#       TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# 0                                           24.7
# 1                                           24.7
# 2                                           24.7
# 3                                           24.9
# 4                                           24.6
# ...                                          ...
# 8755                                        35.2
# 8756                                        35.0
# 8757                                        33.9
# 8758                                        32.7
# 8759                                         NaN
#
#       TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# 0                                           24.3
# 1                                           24.3
# 2                                           24.4
# 3                                           24.1
# 4                                           24.1
# ...                                          ...
# 8755                                        33.9
# 8756                                        33.3
# 8757                                        32.1
# 8758                                        30.8
# 8759                                         NaN
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# 0                                                 23.4
# 1                                                 23.4
# 2                                                 23.4
# 3                                                 23.5
# 4                                                 23.5
# ...                                                ...
# 8755                                              20.6
# 8756                                              19.7
# 8757                                              22.0
# 8758                                              21.9
# 8759                                               NaN
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8755                                              19.1
# 8756                                              17.9
# 8757                                              18.0
# 8758                                              21.3
# 8759                                               NaN
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                         94.0
# 1                                         94.0
# 2                                         93.0
# 3                                         95.0
# 4                                         95.0
# ...                                        ...
# 8755                                      45.0
# 8756                                      42.0
# 8757                                      55.0
# 8758                                      59.0
# 8759                                       NaN
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         92.0
# 1                                         92.0
# 2                                         91.0
# 3                                         92.0
# 4                                         93.0
# ...                                        ...
# 8755                                      40.0
# 8756                                      39.0
# 8757                                      40.0
# 8758                                      52.0
# 8759                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    94.0
# 1                                    92.0
# 2                                    93.0
# 3                                    95.0
# 4                                    94.0
# ...                                   ...
# 8755                                 41.0
# 8756                                 40.0
# 8757                                 53.0
# 8758                                 59.0
# 8759                                  NaN
#
#       VENTO, DIREÇO HORARIA (gr) (ø (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 8755                                 320.0                         6.6
# 8756                                 339.0                         7.0
# 8757                                 105.0                         6.0
# 8758                                  96.0                         4.0
# 8759                                   NaN                         NaN
#
#       VENTO, VELOCIDADE HORARIA (m/s)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 8755                              3.0
# 8756                              3.4
# 8757                              2.0
# 8758                              1.5
# 8759                              NaN
#
# [26280 rows x 19 columns]

# %%
#Definindo coluna data como indice
data = df_concat["DATA"].values
index = pd.DatetimeIndex(data, name="Data")
df_concat.drop("DATA", axis=1, inplace=True)
df_concat.set_index(index, inplace=True)
df_concat
# Out:
#            HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Data
# 2003-01-01      00:00                               NaN
# 2003-01-01      01:00                               NaN
# 2003-01-01      02:00                               NaN
# 2003-01-01      03:00                               NaN
# 2003-01-01      04:00                               NaN
# ...               ...                               ...
# 2023-12-31      19:00                               0.0
# 2023-12-31      20:00                               0.0
# 2023-12-31      21:00                               0.0
# 2023-12-31      22:00                               0.0
# 2023-12-31      23:00                               NaN
#
#             PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# Data
# 2003-01-01                                                NaN
# 2003-01-01                                                NaN
# 2003-01-01                                                NaN
# 2003-01-01                                                NaN
# 2003-01-01                                                NaN
# ...                                                       ...
# 2023-12-31                                              987.4
# 2023-12-31                                              986.7
# 2023-12-31                                              986.8
# 2023-12-31                                              986.9
# 2023-12-31                                                NaN
#
#             PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# Data
# 2003-01-01                                              NaN
# 2003-01-01                                              NaN
# 2003-01-01                                              NaN
# 2003-01-01                                              NaN
# 2003-01-01                                              NaN
# ...                                                     ...
# 2023-12-31                                            988.8
# 2023-12-31                                            987.4
# 2023-12-31                                            986.8
# 2023-12-31                                            987.0
# 2023-12-31                                              NaN
#
#             PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# Data
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# ...                                                      ...
# 2023-12-31                                             987.4
# 2023-12-31                                             986.7
# 2023-12-31                                             986.6
# 2023-12-31                                             986.8
# 2023-12-31                                               NaN
#
#             RADIACAO GLOBAL (KJ/mý)  \
# Data
# 2003-01-01                      NaN
# 2003-01-01                      NaN
# 2003-01-01                      NaN
# 2003-01-01                      NaN
# 2003-01-01                      NaN
# ...                             ...
# 2023-12-31                   2575.3
# 2023-12-31                   1760.8
# 2023-12-31                   1127.5
# 2023-12-31                    490.1
# 2023-12-31                      NaN
#
#             TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)  \
# Data
# 2003-01-01                                          24.3
# 2003-01-01                                          24.7
# 2003-01-01                                          24.4
# 2003-01-01                                          24.1
# 2003-01-01                                          24.5
# ...                                                  ...
# 2023-12-31                                          34.4
# 2023-12-31                                          33.4
# 2023-12-31                                          32.5
# 2023-12-31                                          30.8
# 2023-12-31                                           NaN
#
#             TEMPERATURA DO PONTO DE ORVALHO (øC)  \
# Data
# 2003-01-01                                  23.3
# 2003-01-01                                  23.3
# 2003-01-01                                  23.2
# 2003-01-01                                  23.2
# 2003-01-01                                  23.4
# ...                                          ...
# 2023-12-31                                  19.4
# 2023-12-31                                  18.0
# 2023-12-31                                  21.8
# 2023-12-31                                  21.8
# 2023-12-31                                   NaN
#
#             TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)  \
# Data
# 2003-01-01                                        24.7
# 2003-01-01                                        24.7
# 2003-01-01                                        24.7
# 2003-01-01                                        24.9
# 2003-01-01                                        24.6
# ...                                                ...
# 2023-12-31                                        35.2
# 2023-12-31                                        35.0
# 2023-12-31                                        33.9
# 2023-12-31                                        32.7
# 2023-12-31                                         NaN
#
#             TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)  \
# Data
# 2003-01-01                                        24.3
# 2003-01-01                                        24.3
# 2003-01-01                                        24.4
# 2003-01-01                                        24.1
# 2003-01-01                                        24.1
# ...                                                ...
# 2023-12-31                                        33.9
# 2023-12-31                                        33.3
# 2023-12-31                                        32.1
# 2023-12-31                                        30.8
# 2023-12-31                                         NaN
#
#             TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)  \
# Data
# 2003-01-01                                              23.4
# 2003-01-01                                              23.4
# 2003-01-01                                              23.4
# 2003-01-01                                              23.5
# 2003-01-01                                              23.5
# ...                                                      ...
# 2023-12-31                                              20.6
# 2023-12-31                                              19.7
# 2023-12-31                                              22.0
# 2023-12-31                                              21.9
# 2023-12-31                                               NaN
#
#             TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)  \
# Data
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# 2003-01-01                                               NaN
# ...                                                      ...
# 2023-12-31                                              19.1
# 2023-12-31                                              17.9
# 2023-12-31                                              18.0
# 2023-12-31                                              21.3
# 2023-12-31                                               NaN
#
#             UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# Data
# 2003-01-01                                      94.0
# 2003-01-01                                      94.0
# 2003-01-01                                      93.0
# 2003-01-01                                      95.0
# 2003-01-01                                      95.0
# ...                                              ...
# 2023-12-31                                      45.0
# 2023-12-31                                      42.0
# 2023-12-31                                      55.0
# 2023-12-31                                      59.0
# 2023-12-31                                       NaN
#
#             UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# Data
# 2003-01-01                                      92.0
# 2003-01-01                                      92.0
# 2003-01-01                                      91.0
# 2003-01-01                                      92.0
# 2003-01-01                                      93.0
# ...                                              ...
# 2023-12-31                                      40.0
# 2023-12-31                                      39.0
# 2023-12-31                                      40.0
# 2023-12-31                                      52.0
# 2023-12-31                                       NaN
#
#             UMIDADE RELATIVA DO AR, HORARIA (%)  \
# Data
# 2003-01-01                                 94.0
# 2003-01-01                                 92.0
# 2003-01-01                                 93.0
# 2003-01-01                                 95.0
# 2003-01-01                                 94.0
# ...                                         ...
# 2023-12-31                                 41.0
# 2023-12-31                                 40.0
# 2023-12-31                                 53.0
# 2023-12-31                                 59.0
# 2023-12-31                                  NaN
#
#             VENTO, DIREÇO HORARIA (gr) (ø (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# Data
# 2003-01-01                                   NaN                         NaN
# 2003-01-01                                   NaN                         NaN
# 2003-01-01                                   NaN                         NaN
# 2003-01-01                                   NaN                         NaN
# 2003-01-01                                   NaN                         NaN
# ...                                          ...                         ...
# 2023-12-31                                 320.0                         6.6
# 2023-12-31                                 339.0                         7.0
# 2023-12-31                                 105.0                         6.0
# 2023-12-31                                  96.0                         4.0
# 2023-12-31                                   NaN                         NaN
#
#             VENTO, VELOCIDADE HORARIA (m/s)
# Data
# 2003-01-01                              NaN
# 2003-01-01                              NaN
# 2003-01-01                              NaN
# 2003-01-01                              NaN
# 2003-01-01                              NaN
# ...                                     ...
# 2023-12-31                              3.0
# 2023-12-31                              3.4
# 2023-12-31                              2.0
# 2023-12-31                              1.5
# 2023-12-31                              NaN
#
# [26280 rows x 18 columns]

# %%
df_concat.columns.tolist()
colunas = [
    ('HORA (UTC)',''),
 ('PRECIPITAÇÃO','PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'),
 ('PRESSAO','PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)'),
 ('PRESSAO','PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)'),
 ('PRESSAO','PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)'),
 ('RADIACAO','RADIACAO GLOBAL (KJ/mý)'),
 ('TEMPERATURA','TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)'),
 ('TEMPERATURA','TEMPERATURA DO PONTO DE ORVALHO (øC)'),
 ('TEMPERATURA','TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)'),
 ('TEMPERATURA','TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)'),
 ('TEMPERATURA','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)'),
 ('TEMPERATURA','TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)'),
 ('UMIDADE','UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)'),
 ('UMIDADE','UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)'),
 ('UMIDADE','UMIDADE RELATIVA DO AR, HORARIA (%)'),
 ('VENTO','VENTO, DIRE\x80ÇO HORARIA (gr) (ø (gr))'),
 ('VENTO','VENTO, RAJADA MAXIMA (m/s)'),
 ('VENTO','VENTO, VELOCIDADE HORARIA (m/s)')]

df_concat.columns = pd.MultiIndex.from_tuples(colunas)

# %% [markdown]
# 3. Analise do dataframe

# %%
df_concat.groupby(df_concat.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max'])
# Out:
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.105662  31.0
# 2013                              0.0  0.144678  59.0
# 2023                              0.0  0.124637  41.2

# %%
df_concat.groupby(df_concat.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max'])
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         12.2  26.072362  38.9
# 2013                                          8.9  26.319622  39.2
# 2023                                         10.0  28.599459  43.2
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                  2.9  19.299684  24.9
# 2013                                 -4.3  18.643467  25.2
# 2023                                  3.8  17.604061  24.3
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       13.5  26.722075  39.2
# 2013                                        9.1  26.924634  39.8
# 2023                                       10.2  29.279461  43.3
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       11.7  25.437100  38.0
# 2013                                        8.8  25.748959  37.7
# 2023                                        9.9  27.935143  42.0
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              3.8  19.833669  25.7
# 2013                                             -3.2  19.134039  25.8
# 2023                                              5.0  18.147457  24.9
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              2.4  18.638451  24.2
# 2013                                             -6.4  18.166259  24.0
# 2023                                              2.9  17.089496  23.5

# %%
janeiro = df_concat.loc[df_concat.index.month == 1]
janeiro.groupby(janeiro.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max'])
# Out:
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.226794  13.6
# 2013                              0.0  0.249462  18.0
# 2023                              0.0  0.373333  41.2

# %%
janeiro.groupby(janeiro.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max'])
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         22.7  26.809274  35.8
# 2013                                         22.7  26.451613  34.7
# 2023                                         22.1  27.461085  35.5
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                 20.1  22.842204  24.9
# 2013                                 18.5  22.298790  25.2
# 2023                                 12.8  20.190853  23.0
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       23.2  27.311156  35.8
# 2013                                       22.8  26.955780  35.0
# 2023                                       22.4  28.054264  35.8
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       22.5  26.307527  35.2
# 2013                                       22.4  25.956183  33.3
# 2023                                       22.0  26.847907  34.2
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                             21.0  23.276747  25.7
# 2013                                             19.4  22.739382  25.8
# 2023                                             13.8  20.747597  23.7
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                             19.8  22.234211  23.9
# 2013                                             17.9  21.854570  24.0
# 2023                                             12.3  19.705891  22.4

# %%
verao = df_concat[(df_concat.index.month == 1) | (df_concat.index.month == 2) | (df_concat.index.month == 3)]
outono = df_concat[(df_concat.index.month == 4) | (df_concat.index.month == 5) | (df_concat.index.month == 6)]
inverno = df_concat[(df_concat.index.month == 7) | (df_concat.index.month == 8) | (df_concat.index.month == 9)]
primavera = df_concat[(df_concat.index.month == 10) | (df_concat.index.month == 11) | (df_concat.index.month == 12)]

# %%
print(verao.groupby(verao.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max']))
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         18.2  26.633534  35.8
# 2013                                         21.1  26.565733  35.8
# 2023                                         21.6  27.576530  36.1
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                 16.3  22.442612  24.9
# 2013                                 15.3  22.038189  25.2
# 2023                                 12.8  20.555696  23.5
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       18.3  27.165354  36.2
# 2013                                       21.4  27.088282  36.3
# 2023                                       21.7  28.189030  37.4
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       17.9  26.108893  35.2
# 2013                                       21.0  26.064706  34.7
# 2023                                       21.4  26.960707  35.5
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                             16.7  22.921075  25.7
# 2013                                             16.4  22.519141  25.8
# 2023                                             13.8  21.109705  24.2
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                             16.3  21.874195  24.2
# 2013                                             14.6  21.574463  24.0
# 2023                                             12.3  20.047416  22.7

# %%
print(outono.groupby(outono.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max']))
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         14.1  25.303073  35.6
# 2013                                         16.1  25.731714  34.7
# 2023                                         10.0  25.895853  35.5
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                  8.4  19.165229  24.6
# 2013                                 11.4  19.612236  24.9
# 2023                                  6.5  17.686067  24.0
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       14.6  25.966055  36.1
# 2013                                       16.6  26.295692  34.8
# 2023                                       10.2  26.515610  36.0
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       13.9  24.656927  35.1
# 2013                                       16.0  25.199358  33.7
# 2023                                        9.9  25.312908  34.9
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              9.6  19.688165  25.5
# 2013                                             12.3  20.078002  25.0
# 2023                                              7.7  18.193150  24.3
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              7.7  18.670183  23.8
# 2013                                             10.4  19.182631  23.4
# 2023                                              5.4  17.218639  23.3

# %%
print(inverno.groupby(inverno.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max']))
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         12.2  25.173822  38.9
# 2013                                          8.9  26.029891  39.2
# 2023                                         15.1  29.406840  41.4
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                  2.9  14.684601  23.3
# 2013                                 -4.3  12.102989  21.9
# 2023                                  3.8  13.955951  23.3
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       13.5  25.966078  39.2
# 2013                                        9.1  26.766803  39.8
# 2023                                       15.2  30.172230  41.8
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       11.7  24.401585  38.0
# 2013                                        8.8  25.340716  37.7
# 2023                                       14.7  28.675787  40.5
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              3.8  15.280299  23.8
# 2013                                             -3.2  12.621196  22.3
# 2023                                              5.0  14.498404  24.8
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              2.4  14.119158  23.1
# 2013                                             -6.4  11.585507  21.5
# 2023                                              2.9  13.426676  22.2

# %%
print(primavera.groupby(primavera.index.year)['TEMPERATURA'].aggregate(['min', 'mean', 'max']))
# Out:
#                                       TEMPERATURA                   \
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
#                                               min       mean   max
# Data
# 2003                                         18.6  27.302008  37.7
# 2013                                         20.3  26.951585  37.4
# 2023                                         22.7  31.755285  43.2
#
#                                                             \
#      TEMPERATURA DO PONTO DE ORVALHO (øC)
#                                       min       mean   max
# Data
# 2003                                 11.5  21.155924  24.8
# 2013                                 11.5  20.933333  24.5
# 2023                                  5.6  18.781660  24.3
#
#                                                                   \
#      TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       18.7  27.906978  38.0
# 2013                                       20.6  27.545245  38.3
# 2023                                       23.1  32.482450  43.3
#
#                                                                   \
#      TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
#                                             min       mean   max
# Data
# 2003                                       18.5  26.710592  37.3
# 2013                                       20.2  26.394022  36.4
# 2023                                       22.3  31.037275  42.0
#
#                                                                         \
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                             13.1  21.693775  25.3
# 2013                                             11.8  21.430118  25.6
# 2023                                              8.8  19.360551  24.9
#
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
#                                                   min       mean   max
# Data
# 2003                                              8.4  20.635592  24.2
# 2013                                             10.9  20.436277  23.4
# 2023                                              5.3  18.227996  23.5

# %%
print(verao.groupby(verao.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max']))
print(outono.groupby(outono.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max']))
print(inverno.groupby(inverno.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max']))
print(primavera.groupby(primavera.index.year)['PRECIPITAÇÃO'].aggregate(['min', 'mean', 'max']))
# Out:
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.205019  13.6
# 2013                              0.0  0.257610  59.0
# 2023                              0.0  0.312025  41.2
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.077706  16.2
# 2013                              0.0  0.064312  34.0
# 2023                              0.0  0.095806  15.6
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.000091   0.2
# 2013                              0.0  0.017754  10.4
# 2023                              0.0  0.020064  12.6
#                          PRECIPITAÇÃO
#      PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                   min      mean   max
# Data
# 2003                              0.0  0.161847  31.0
# 2013                              0.0  0.241395  48.4
# 2023                              0.0  0.090746  13.8

# %%
df_concat_periodo = df_concat.loc[df_concat.index.get_level_values("Data").month == 9]
df_concat_periodo = df_concat_periodo.loc[df_concat_periodo.index.get_level_values("Data").day == 28]
df_concat_periodo
# Out:
#            HORA (UTC)                     PRECIPITAÇÃO  \
#                       PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# Data
# 2003-09-28      00:00                              0.0
# 2003-09-28      01:00                              0.0
# 2003-09-28      02:00                              0.0
# 2003-09-28      03:00                              0.0
# 2003-09-28      04:00                              0.0
# ...               ...                              ...
# 2023-09-28      19:00                              0.0
# 2023-09-28      20:00                              0.0
# 2023-09-28      21:00                              0.0
# 2023-09-28      22:00                              0.0
# 2023-09-28      23:00                              NaN
#
#                                                          PRESSAO  \
#            PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# Data
# 2003-09-28                                              980.3
# 2003-09-28                                              983.1
# 2003-09-28                                              984.5
# 2003-09-28                                              985.1
# 2003-09-28                                              985.7
# ...                                                       ...
# 2023-09-28                                              987.0
# 2023-09-28                                              986.2
# 2023-09-28                                              986.3
# 2023-09-28                                              987.0
# 2023-09-28                                                NaN
#
#                                                             \
#            PRESSÇO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# Data
# 2003-09-28                                           980.3
# 2003-09-28                                           983.1
# 2003-09-28                                           984.5
# 2003-09-28                                           985.1
# 2003-09-28                                           985.7
# ...                                                    ...
# 2023-09-28                                           987.8
# 2023-09-28                                           987.0
# 2023-09-28                                           986.3
# 2023-09-28                                           987.0
# 2023-09-28                                             NaN
#
#                                                              \
#            PRESSÇO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# Data
# 2003-09-28                                            979.1
# 2003-09-28                                            980.3
# 2003-09-28                                            983.1
# 2003-09-28                                            984.5
# 2003-09-28                                            985.1
# ...                                                     ...
# 2023-09-28                                            987.0
# 2023-09-28                                            986.2
# 2023-09-28                                            986.1
# 2023-09-28                                            986.3
# 2023-09-28                                              NaN
#
#                           RADIACAO  \
#            RADIACAO GLOBAL (KJ/mý)
# Data
# 2003-09-28                     NaN
# 2003-09-28                     NaN
# 2003-09-28                     NaN
# 2003-09-28                     NaN
# 2003-09-28                     NaN
# ...                            ...
# 2023-09-28                  2318.9
# 2023-09-28                  1541.4
# 2023-09-28                   680.8
# 2023-09-28                    74.5
# 2023-09-28                     NaN
#
#                                             TEMPERATURA  \
#            TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
# Data
# 2003-09-28                                         27.1
# 2003-09-28                                         27.4
# 2003-09-28                                         25.5
# 2003-09-28                                         24.7
# 2003-09-28                                         24.3
# ...                                                 ...
# 2023-09-28                                         34.1
# 2023-09-28                                         33.5
# 2023-09-28                                         33.3
# 2023-09-28                                         32.3
# 2023-09-28                                          NaN
#
#                                                  \
#            TEMPERATURA DO PONTO DE ORVALHO (øC)
# Data
# 2003-09-28                                 22.0
# 2003-09-28                                 21.2
# 2003-09-28                                 23.0
# 2003-09-28                                 22.6
# 2003-09-28                                 22.4
# ...                                         ...
# 2023-09-28                                 17.1
# 2023-09-28                                 17.2
# 2023-09-28                                 18.0
# 2023-09-28                                 18.6
# 2023-09-28                                  NaN
#
#                                                        \
#            TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
# Data
# 2003-09-28                                       28.2
# 2003-09-28                                       27.8
# 2003-09-28                                       27.4
# 2003-09-28                                       25.5
# 2003-09-28                                       24.7
# ...                                               ...
# 2023-09-28                                       34.1
# 2023-09-28                                       34.5
# 2023-09-28                                       34.3
# 2023-09-28                                       33.3
# 2023-09-28                                        NaN
#
#                                                        \
#            TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
# Data
# 2003-09-28                                       26.5
# 2003-09-28                                       26.5
# 2003-09-28                                       25.5
# 2003-09-28                                       24.7
# 2003-09-28                                       24.3
# ...                                               ...
# 2023-09-28                                       32.3
# 2023-09-28                                       33.2
# 2023-09-28                                       33.3
# 2023-09-28                                       32.3
# 2023-09-28                                        NaN
#
#                                                              \
#            TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
# Data
# 2003-09-28                                             22.1
# 2003-09-28                                             22.6
# 2003-09-28                                             23.1
# 2003-09-28                                             23.0
# 2003-09-28                                             22.6
# ...                                                     ...
# 2023-09-28                                             18.0
# 2023-09-28                                             17.7
# 2023-09-28                                             18.1
# 2023-09-28                                             18.6
# 2023-09-28                                              NaN
#
#                                                              \
#            TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
# Data
# 2003-09-28                                             21.2
# 2003-09-28                                             21.1
# 2003-09-28                                             21.2
# 2003-09-28                                             22.6
# 2003-09-28                                             22.3
# ...                                                     ...
# 2023-09-28                                             16.8
# 2023-09-28                                             16.8
# 2023-09-28                                             16.9
# 2023-09-28                                             17.8
# 2023-09-28                                              NaN
#
#                                             UMIDADE  \
#            UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# Data
# 2003-09-28                                     76.0
# 2003-09-28                                     79.0
# 2003-09-28                                     86.0
# 2003-09-28                                     88.0
# 2003-09-28                                     89.0
# ...                                             ...
# 2023-09-28                                     41.0
# 2023-09-28                                     38.0
# 2023-09-28                                     40.0
# 2023-09-28                                     44.0
# 2023-09-28                                      NaN
#
#                                                      \
#            UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# Data
# 2003-09-28                                     66.0
# 2003-09-28                                     67.0
# 2003-09-28                                     69.0
# 2003-09-28                                     85.0
# 2003-09-28                                     87.0
# ...                                             ...
# 2023-09-28                                     36.0
# 2023-09-28                                     36.0
# 2023-09-28                                     37.0
# 2023-09-28                                     40.0
# 2023-09-28                                      NaN
#
#                                                 \
#            UMIDADE RELATIVA DO AR, HORARIA (%)
# Data
# 2003-09-28                                74.0
# 2003-09-28                                69.0
# 2003-09-28                                86.0
# 2003-09-28                                88.0
# 2003-09-28                                89.0
# ...                                        ...
# 2023-09-28                                37.0
# 2023-09-28                                38.0
# 2023-09-28                                40.0
# 2023-09-28                                44.0
# 2023-09-28                                 NaN
#
#                                           VENTO                             \
#            VENTO, DIREÇO HORARIA (gr) (ø (gr)) VENTO, RAJADA MAXIMA (m/s)
# Data
# 2003-09-28                                 71.0                        1.8
# 2003-09-28                                 73.0                        2.1
# 2003-09-28                                240.0                        1.8
# 2003-09-28                                276.0                        2.3
# 2003-09-28                                308.0                        2.3
# ...                                         ...                        ...
# 2023-09-28                                278.0                        3.9
# 2023-09-28                                209.0                        3.6
# 2023-09-28                                212.0                        3.6
# 2023-09-28                                192.0                        3.1
# 2023-09-28                                  NaN                        NaN
#
#
#            VENTO, VELOCIDADE HORARIA (m/s)
# Data
# 2003-09-28                             0.8
# 2003-09-28                             0.8
# 2003-09-28                             1.1
# 2003-09-28                             0.6
# 2003-09-28                             0.1
# ...                                    ...
# 2023-09-28                             0.9
# 2023-09-28                             1.6
# 2023-09-28                             1.3
# 2023-09-28                             0.7
# 2023-09-28                             NaN
#
# [72 rows x 18 columns]

# %%
# vendo valores de hora
print((df_concat_periodo)['HORA (UTC)'].unique())
# Out:
# ['00:00' '01:00' '02:00' '03:00' '04:00' '05:00' '06:00' '07:00' '08:00'
#  '09:00' '10:00' '11:00' '12:00' '13:00' '14:00' '15:00' '16:00' '17:00'
#  '18:00' '19:00' '20:00' '21:00' '22:00' '23:00']

# %%
horas = {'00:00': 'madrugada', '01:00': 'madrugada', '02:00': 'madrugada', '03:00': 'madrugada', '04:00': 'madrugada', '05:00': 'madrugada',
           '06:00': 'manha', '07:00': 'manha', '08:00': 'manha', '09:00': 'manha', '10:00': 'manha', '11:00': 'manha', '12:00': 'manha',
           '13:00': 'tarde', '14:00': 'tarde', '15:00': 'tarde', '16:00': 'tarde', '17:00': 'tarde', '18:00': 'tarde',
           '19:00': 'noite', '20:00': 'noite', '21:00': 'noite', '22:00': 'noite', '23:00': 'noite'}

temperatura = df_concat_periodo.groupby('HORA (UTC)')['TEMPERATURA'].mean()
precipitacao_hora = df_concat_periodo.groupby('HORA (UTC)')['PRECIPITAÇÃO'].mean()

# concatenando os dataframes
prec_temp_por_hora = pd.concat([precipitacao_hora, temperatura], axis=1)
prec_temp_por_hora.groupby(horas).mean()
# Out:
#                                PRECIPITAÇÃO  \
#            PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# HORA (UTC)
# madrugada                          0.000000
# manha                              0.009524
# noite                              0.000000
# tarde                              0.000000
#
#                                             TEMPERATURA  \
#            TEMPERATURA DO AR - BULBO SECO, HORARIA (øC)
# HORA (UTC)
# madrugada                                     27.833333
# manha                                         25.200000
# noite                                         32.753333
# tarde                                         32.327778
#
#                                                  \
#            TEMPERATURA DO PONTO DE ORVALHO (øC)
# HORA (UTC)
# madrugada                             17.641667
# manha                                 17.328571
# noite                                 18.243333
# tarde                                 17.855556
#
#                                                        \
#            TEMPERATURA MµXIMA NA HORA ANT. (AUT) (øC)
# HORA (UTC)
# madrugada                                   28.691667
# manha                                       25.633333
# noite                                       33.743333
# tarde                                       32.661111
#
#                                                        \
#            TEMPERATURA MÖNIMA NA HORA ANT. (AUT) (øC)
# HORA (UTC)
# madrugada                                   27.661111
# manha                                       24.542857
# noite                                       32.480000
# tarde                                       30.822222
#
#                                                              \
#            TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (øC)
# HORA (UTC)
# madrugada                                         18.166667
# manha                                             17.623810
# noite                                             18.613333
# tarde                                             18.494444
#
#
#            TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (øC)
# HORA (UTC)
# madrugada                                         17.269444
# manha                                             16.928571
# noite                                             17.706667
# tarde                                             17.216667

# %% [markdown]
# ### Exercício 1: Tratando séries temporais indexadas por tempo

# %% [markdown]
# ##### 1. Analisando as colunas relacionadas e precipitações e temperaturas, mostre num subplot a evolução das temperaturas médias e acumulado de precipitações nos tres anos.

# %%
anos = [2003, 2013, 2023]
df_filtrado = df_concat[df_concat.index.get_level_values("Data").year.isin(anos)]

# %%
media_mensal = df_filtrado.groupby([df_filtrado.index.get_level_values(0).year, df_filtrado.index.get_level_values(0).month])['PRECIPITAÇÃO'].mean()

# %%
# Plotando o gráfico
fig, ax = plt.subplots(figsize=(10, 6))
for ano in anos:
    media_mensal.loc[ano].plot(ax=ax, label=str(ano))
    # Adicionando título para cada linha
    ax.lines[-1].set_label(str(ano))

ax.set_xticks(range(1, 13))
ax.set_xticklabels(['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
ax.set_xlabel('Mês')
ax.set_ylabel('Média de Precipitação (mm)')
ax.set_title('Média de Precipitação por Mês (2003, 2013, 2023)')
ax.legend(title='Ano', loc='upper left')
